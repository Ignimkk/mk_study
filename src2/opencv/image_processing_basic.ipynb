# %%
import cv2
import matplotlib.pyplot as plt

# %% [markdown]
# cv2로 이미지 읽고 >> cvtColor BGR에서 RGB로 변환한다 >>  plt로 이미지 띄우기

# %%
img2 = cv2.imread('/home/addinedu/dev_ws/opencv/data/gorilla.jpg')
img2 = cv2.cvtColor(img2, cv2.COLOR_BGR2RGB)
img2 = cv2.resize(img2, (640,480))
plt.imshow(img2);

# %%
img1 = cv2.imread('/home/addinedu/dev_ws/opencv/data/gorilla.jpg')
img1 = cv2.cvtColor(img1, cv2.COLOR_BGR2RGB)
plt.imshow(img1);


img2 = cv2.imread('/home/addinedu/dev_ws/opencv/captured_images/captured_image_9.jpg')
img2 = cv2.cvtColor(img2, cv2.COLOR_BGR2RGB)
plt.imshow(img2);

# %%
img1.shape, img2.shape
# Out:
# ((470, 780, 3), (480, 640, 3))

# %% [markdown]
# img.shape >> (열의 길이(y), 행의 길이(x))
#
# shape은 (y, x, c) = (h, w, c(두께)) 형태임.
#
# 하지만 resize는 (x,y) = (w, h) 형태임

# %%
img2 = cv2.resize(img2, (img1.shape[1], img1.shape[0]))
img1.shape, img2.shape
# Out:
# ((470, 780, 3), (470, 780, 3))

# %%
# Out:
# 947

# %%
blended = cv2.addWeighted(src1=img1, alpha=0.5, src2=img2, beta=0.5, gamma=0)
plt.imshow(blended)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 blended = cv2.addWeighted(src1=img1, alpha=1, src2=img2, beta=0.5, gamma=0)
#       2 plt.imshow(blended)
#
# NameError: name 'img2' is not defined

# %%
img2 = cv2.resize(img2, (600,600))
plt.imshow(img2);

# %%
img2.shape
# Out:
# (470, 780, 3)

# %%
large_img = img1
small_img = img2

x_offset = 0
y_offset = 0

# %%
x_end = x_offset + small_img.shape[1]
y_end = y_offset + small_img.shape[0]

large_img[y_offset:y_end , x_offset:x_end] = small_img

# %%
plt.imshow(large_img)

# %%
img1 = cv2.imread('/home/addinedu/dev_ws/opencv/captured_images/mark_mingi2.jpg')
# img1 = cv2.cvtColor(img1, cv2.COLOR_BGR2RGB)
img1 = cv2.resize(img1, (300,480))
plt.imshow(img1);

# %%
img1.shape
# Out:
# (480, 300, 3)

# %%
img1 = cv2.imread('/home/addinedu/dev_ws/opencv/data/gorilla.jpg')
# img1 = cv2.cvtColor(img1, cv2.COLOR_BGR2RGB)
plt.imshow(img1);


img2 = cv2.imread('/home/addinedu/dev_ws/opencv/captured_images/captured_image_9.jpg')
img2 = cv2.cvtColor(img2, cv2.COLOR_BGR2RGB)
plt.imshow(img2);

# %%
x_offset = img1.shape[1] - img2.shape[1]
y_offset = img1.shape[0] - img2.shape[0]
x_offset, y_offset
# Out:
# (140, -10)

# %%
roi = img2[0:500, 0:300]
plt.imshow(roi);

# %%
img1 = cv2.cvtColor(img1, cv2.COLOR_RGB2GRAY)
plt.imshow(img1, cmap='gray');

# %%
mask_inv = cv2.bitwise_not(img1)
plt.imshow(mask_inv, cmap='gray');

# %%
fg.shape
# Out:
# (480, 300)

# %%
fg = cv2.bitwise_or(img1,img1, mask=mask_inv)
fg_color = cv2.cvtColor(fg, cv2.COLOR_GRAY2BGR)

# roi와 fg 이미지를 합성
final_roi = cv2.bitwise_or(roi, fg_color)
plt.imshow(final_roi)

# %%
roi.shape
# Out:
# (480, 300, 3)

# %%
final_roi = cv2.bitwise_or(roi, fg)
plt.imshow(final_roi);
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[67], line 1
# ----> 1 final_roi = cv2.bitwise_or(roi, fg)
#       2 plt.imshow(final_roi);
#
# error: OpenCV(4.9.0) /io/opencv/modules/core/src/arithm.cpp:212: error: (-209:Sizes of input arguments do not match) The operation is neither 'array op array' (where arrays have the same size and type), nor 'array op scalar', nor 'scalar op array' in function 'binary_op'

# %%
img2[0:500, 0:300] = final_roi
plt.imshow(img2);

# %%
import numpy as np
x = np.array(img1)
# print(x)
x.shape
# Out:
# (1394, 947, 3)

# %%
img1 = cv2.imread('/home/addinedu/dev_ws/opencv/data/gorilla.jpg')
img1 = cv2.cvtColor(img1, cv2.COLOR_BGR2RGB)
plt.imshow(img1);


img2 = cv2.imread('/home/addinedu/dev_ws/opencv/captured_images/captured_image_9.jpg')
img2 = cv2.cvtColor(img2, cv2.COLOR_BGR2RGB)
plt.imshow(img2);

# %%
src = cv2.imread('/home/addinedu/dev_ws/opencv/captured_images/captured_image_9.jpg', cv2.IMREAD_COLOR)
src = cv2.cvtColor(src, cv2.COLOR_BGR2RGB)

plt.imshow(src)

# %%
mask = cv2.imread("/home/addinedu/dev_ws/opencv/mask2.bmp", cv2.IMREAD_GRAYSCALE)
plt.imshow(mask, cmap='gray');

# %%
dst= cv2.imread('/home/addinedu/dev_ws/opencv/gorilla.bmp', cv2.IMREAD_COLOR)
dst =cv2.cvtColor(dst, cv2.COLOR_BGR2RGB)


plt.imshow(dst);

# %%
mask = cv2.resize(mask, (1280, 960))
src = cv2.resize(src, (1280, 960))
dst = cv2.resize(dst, (1280, 960))

print(src.shape)
print(mask.shape)
print(dst.shape)
# Out:
# (960, 1280, 3)
# (960, 1280)
# (960, 1280, 3)

# %%
print(src.shape)
print(mask.shape)
print(dst.shape)
# Out:
# (240, 320, 3)
# (240, 320)
# (470, 780, 3)

# %%
plt.imshow(cv2.copyTo(src, mask, dst))

# %%
x_offset = 0
y_offset = 0

# dst 이미지에 src 이미지를 합성
result = cv2.copyTo(src, mask, dst[y_offset:y_offset+src.shape[0], x_offset:x_offset+src.shape[1]])
plt.imshow(result)

# %%
import cv2

src = cv2.imread('/home/addinedu/dev_ws/opencv/captured_images/captured_image_9.jpg', cv2.IMREAD_COLOR)
mask = cv2.imread("/home/addinedu/dev_ws/opencv/mask2.bmp", cv2.IMREAD_GRAYSCALE)

src = cv2.cvtColor(src, cv2.COLOR_BGR2RGB)

roi = cv2.bitwise_and(src, src, mask=mask)

new_image = cv2.imread('/home/addinedu/dev_ws/opencv/gorilla.bmp', cv2.IMREAD_COLOR)
new_image = cv2.cvtColor(new_image, cv2.COLOR_BGR2RGB)

x_offset = 0  # 삽입할 위치의 x 좌표
y_offset = 0  # 삽입할 위치의 y 좌표

roi_resized = cv2.resize(roi, (new_image.shape[1], new_image.shape[0]))

new_image[y_offset:y_offset+roi_resized.shape[0], x_offset:x_offset+roi_resized.shape[1]] = roi_resized

cv2.imwrite("result_image.jpg", cv2.cvtColor(new_image, cv2.COLOR_RGB2BGR))
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[88], line 11
#       8 src = cv2.cvtColor(src, cv2.COLOR_BGR2RGB)
#      10 # mask 이미지를 이용하여 src 이미지에서 관심 영역 선택
# ---> 11 roi = cv2.bitwise_and(src, src, mask=mask)
#      13 # 새로운 이미지 생성
#      14 new_image = cv2.imread('/home/addinedu/dev_ws/opencv/gorilla.bmp', cv2.IMREAD_COLOR)
#
# error: OpenCV(4.9.0) /io/opencv/modules/core/src/arithm.cpp:230: error: (-215:Assertion failed) (mtype == CV_8U || mtype == CV_8S) && _mask.sameSize(*psrc1) in function 'binary_op'
