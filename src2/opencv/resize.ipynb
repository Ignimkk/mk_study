# %%
import numpy as np
import matplotlib.pyplot as plt
# from PIL import Image
import cv2

# %%
img = cv2.imread('/home/addinedu/dev_ws/opencv/data/gigi.png')
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (1394, 947, 3)

# %%
plt.imshow(img)

# %%
fix_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(fix_img)

# %%
img_gray = cv2.imread('/home/addinedu/dev_ws/opencv/data/gigi.png', cv2.IMREAD_GRAYSCALE)
plt.imshow(img_gray, cmap='gray');

# %%
img.shape
# Out:
# (1394, 947, 3)

# %%
new_img = cv2.resize(fix_img, (600,600))
plt.imshow(new_img);

# %%
plt.imshow(cv2.flip(fix_img,0));

# %%
plt.imshow(img_gray,cmap='gray');

# %%
cv2.imwrite('./data/monster.jpg', img_gray)
# Out:
# True
