# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
import cv2

# %%
monster = Image.open('/home/addinedu/dev_ws/opencv/data/gigi.png')
monster
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=947x1394>

# %%
type(monster)
# Out:
# PIL.PngImagePlugin.PngImageFile

# %%
monster_arr = np.asarray(monster)
type(monster_arr)
# Out:
# numpy.ndarray

# %%
monster_arr.shape
# Out:
# (1394, 947, 4)

# %%
plt.imshow(monster_arr)

# %%
monster_red = monster_arr.copy()
plt.imshow(monster_red[:,:,0])

# %%
monster_red = monster_arr.copy()
plt.imshow(monster_red[:,:,0], cmap = 'gray')

# %%
monster_red = monster_arr.copy()
plt.imshow(monster_red[:,:,2], cmap = 'gray')

# %%
monster_red[:,:,2] = 0
plt.imshow(monster_red)
